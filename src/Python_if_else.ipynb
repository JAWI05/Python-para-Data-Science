# %% [markdown]
# Desvio condicional (if - else)
#   - cria uma condição true/false
#   - simples, composto, encadeado

# %% [markdown]
# Pygame - biblioteca de jogos

# %%
print('Esse jogo irá calcular o número de pontos de um jogador em uma fase.')

pontos = float(input('Digite quantos pontos o jogador fez na fase 1: '))

if pontos >= 1000:
  print("Parabéns!! Você passou para a fase 2.")
else:
  print("Infelizmente, você não passou para a segunda fase.")
  while pontos < 1000:
    pontos = float(input('Digite a quantidade de pontos da segunda tentativa: '))
    if pontos >= 1000:
      print('Você passou para a fase 2')
    else:
      print('Você não passou para a fase 2')
# Out:
# Esse jogo irá calcular o número de pontos de um jogador em uma fase.
# Digite quantos pontos o jogador fez na fase 1: 34
# Infelizmente, você não passou para a segunda fase.
# Digite a quantidade de pontos da segunda tentativa: 23
# Você não passou para a fase 2
# Digite a quantidade de pontos da segunda tentativa: 1000
# Você passou para a fase 2

# %%
# exemplo 1
num = int(input('Digite um número: '))
if num % 2 == 0:
  print('O número é par')
else:
  print('O número é ímpar')
# Out:
# Digite um número: 34
# O número é par

# %%
# exercício 2
idade = int(input('Digite a sua idade: '))
if idade >= 18:
  print('Você é maior de idade')
else:
  print('Você é menor de idade')
# Out:
# Digite a sua idade: 17
# Você é menor de idade

# %%
print('Nesse jogo o usuário tem que acertar o número secreto')
num = int(input('Digite um número: '))
if num == 15:
  print('Você acertou o número secreto')
else:
